# %% [markdown]
# # Fluxos

# %% [markdown]
# ## Fluxo para criação de planilhas mensais

# %%
from src.workflows.planilha_mensal_workflow import workflow_automacao_mensal

workflow_automacao_mensal()
# Out:
# ▶️Iniciando automação...
# ⚫Duplicação
#  ➡️Mês anterior: Março
#  ➡️Mês atual: Abril
#  ⏳Validando existência da planilha do mês atual...
#  ✅Duplicado com sucesso
#  ⏳Carregando...
#
# ⚫Validação e sincronizando planilhas
# 🔍 Verificando arquivo: abril
# DEBUG IDs recebidos:
# MES: 1wbBJU_frjOIPQKJMw7knEeosEoWm0hScyo6xfmGMyng
# CONTROLE: 1ILmNbWWKHAWOg_hDpD-GTN8qAvuw0DDmbp-TxHT5AYI
# DEBUG ID recebido: 1ILmNbWWKHAWOg_hDpD-GTN8qAvuw0DDmbp-TxHT5AYI <class 'str'>
# ⏳ Tentativa 1 abrindo planilha 1ILmNbWWKHAWOg_hDpD-GTN8qAvuw0DDmbp-TxHT5AYI
# ✅ Planilha disponível
# 📄 Abas encontradas: ['Alunos']
# DEBUG ID recebido: 1wbBJU_frjOIPQKJMw7knEeosEoWm0hScyo6xfmGMyng <class 'str'>
# ⏳ Tentativa 1 abrindo planilha 1wbBJU_frjOIPQKJMw7knEeosEoWm0hScyo6xfmGMyng
# ✅ Planilha disponível
# 📄 Abas encontradas: ['Total', 'Manoela Dualib', 'Thiago', 'Isabella', 'Oto', 'Manoela Salton', 'Matheus', 'Patrick', 'Eduardo', 'Laila']
# Aba 'Oto' já existe
# Aba 'Isabella' já existe
# ✅ Aba 'Enrico' criada
# Aba 'Thiago' já existe
# Aba 'Matheus' já existe
# Aba 'Eduardo' já existe
# Aba 'Patrick' já existe
# Aba 'Manoela Salton' já existe
# Aba 'Manoela Dualib' já existe
#
# ✅Finalizado
